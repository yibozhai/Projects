# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

# %%
#helper Method
def set_frame_style(df, caption=""):
    """Helper function to set dataframe presentation style.
    """
    return df.style.background_gradient(cmap='Blues').set_caption(caption).set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'darkblue'),
        ('font-size', '18px'),
        ('font-weight','bold')
    ]}])

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

train_df.drop(columns=['id'], inplace=True)

# %%
# More Visualized EDA
# print(train_df.shape)
# train_df.head()

cols = train_df.columns.to_list()

display(set_frame_style(train_df[cols].head(),'First Few Rows Of Data'))

display(set_frame_style(train_df[cols].describe(),'Summary Statistics'))

display(set_frame_style(train_df[cols].nunique().to_frame().rename({0:'Unique Value Count'}, axis=1).transpose(), 'Unique Value Counts In Each Column'))

display(set_frame_style(train_df[cols].isna().any().to_frame().transpose(), 'Columns With Nan'))
# Out:
# <style type="text/css">
# #T_5a64e caption {
#   color: darkblue;
#   font-size: 18px;
#   font-weight: bold;
# }
# #T_5a64e_row0_col0, #T_5a64e_row4_col8 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_5a64e_row0_col1, #T_5a64e_row3_col1, #T_5a64e_row4_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_5a64e_row0_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_5a64e_row0_col3, #T_5a64e_row0_col6, #T_5a64e_row0_col9, #T_5a64e_row1_col4, #T_5a64e_row1_col6, #T_5a64e_row1_col10, #T_5a64e_row1_col15, #T_5a64e_row2_col0, #T_5a64e_row2_col1, #T_5a64e_row2_col4, #T_5a64e_row2_col5, #T_5a64e_row2_col6, #T_5a64e_row2_col10, #T_5a64e_row3_col2, #T_5a64e_row3_col7, #T_5a64e_row3_col8, #T_5a64e_row3_col10, #T_5a64e_row4_col2, #T_5a64e_row4_col4, #T_5a64e_row4_col6, #T_5a64e_row4_col7, #T_5a64e_row4_col10, #T_5a64e_row4_col11, #T_5a64e_row4_col12, #T_5a64e_row4_col13, #T_5a64e_row4_col14 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5a64e_row0_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_5a64e_row0_col5 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_5a64e_row0_col7, #T_5a64e_row0_col10, #T_5a64e_row0_col11, #T_5a64e_row0_col12, #T_5a64e_row0_col13, #T_5a64e_row0_col14, #T_5a64e_row0_col15, #T_5a64e_row1_col1, #T_5a64e_row1_col3, #T_5a64e_row1_col5, #T_5a64e_row1_col7, #T_5a64e_row1_col8, #T_5a64e_row1_col11, #T_5a64e_row1_col12, #T_5a64e_row1_col13, #T_5a64e_row1_col14, #T_5a64e_row2_col2, #T_5a64e_row2_col3, #T_5a64e_row2_col7, #T_5a64e_row2_col9, #T_5a64e_row2_col11, #T_5a64e_row2_col12, #T_5a64e_row2_col13, #T_5a64e_row2_col14, #T_5a64e_row3_col3, #T_5a64e_row3_col4, #T_5a64e_row3_col6, #T_5a64e_row3_col9, #T_5a64e_row3_col11, #T_5a64e_row3_col12, #T_5a64e_row3_col13, #T_5a64e_row3_col14, #T_5a64e_row4_col0, #T_5a64e_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5a64e_row0_col8 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_5a64e_row1_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_5a64e_row1_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_5a64e_row1_col9 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_5a64e_row2_col8 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_5a64e_row2_col15 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_5a64e_row3_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_5a64e_row3_col5 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_5a64e_row3_col15 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_5a64e_row4_col5 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_5a64e_row4_col9 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_5a64e_row4_col15 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a64e">
#   <caption>First Few Rows Of Data</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a64e_level0_col0" class="col_heading level0 col0" >store_sales(in millions)</th>
#       <th id="T_5a64e_level0_col1" class="col_heading level0 col1" >unit_sales(in millions)</th>
#       <th id="T_5a64e_level0_col2" class="col_heading level0 col2" >total_children</th>
#       <th id="T_5a64e_level0_col3" class="col_heading level0 col3" >num_children_at_home</th>
#       <th id="T_5a64e_level0_col4" class="col_heading level0 col4" >avg_cars_at home(approx).1</th>
#       <th id="T_5a64e_level0_col5" class="col_heading level0 col5" >gross_weight</th>
#       <th id="T_5a64e_level0_col6" class="col_heading level0 col6" >recyclable_package</th>
#       <th id="T_5a64e_level0_col7" class="col_heading level0 col7" >low_fat</th>
#       <th id="T_5a64e_level0_col8" class="col_heading level0 col8" >units_per_case</th>
#       <th id="T_5a64e_level0_col9" class="col_heading level0 col9" >store_sqft</th>
#       <th id="T_5a64e_level0_col10" class="col_heading level0 col10" >coffee_bar</th>
#       <th id="T_5a64e_level0_col11" class="col_heading level0 col11" >video_store</th>
#       <th id="T_5a64e_level0_col12" class="col_heading level0 col12" >salad_bar</th>
#       <th id="T_5a64e_level0_col13" class="col_heading level0 col13" >prepared_food</th>
#       <th id="T_5a64e_level0_col14" class="col_heading level0 col14" >florist</th>
#       <th id="T_5a64e_level0_col15" class="col_heading level0 col15" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a64e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a64e_row0_col0" class="data row0 col0" >8.610000</td>
#       <td id="T_5a64e_row0_col1" class="data row0 col1" >3.000000</td>
#       <td id="T_5a64e_row0_col2" class="data row0 col2" >2.000000</td>
#       <td id="T_5a64e_row0_col3" class="data row0 col3" >2.000000</td>
#       <td id="T_5a64e_row0_col4" class="data row0 col4" >2.000000</td>
#       <td id="T_5a64e_row0_col5" class="data row0 col5" >10.300000</td>
#       <td id="T_5a64e_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_5a64e_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_5a64e_row0_col8" class="data row0 col8" >32.000000</td>
#       <td id="T_5a64e_row0_col9" class="data row0 col9" >36509.000000</td>
#       <td id="T_5a64e_row0_col10" class="data row0 col10" >0.000000</td>
#       <td id="T_5a64e_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_5a64e_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_5a64e_row0_col13" class="data row0 col13" >0.000000</td>
#       <td id="T_5a64e_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_5a64e_row0_col15" class="data row0 col15" >62.090000</td>
#     </tr>
#     <tr>
#       <th id="T_5a64e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a64e_row1_col0" class="data row1 col0" >5.000000</td>
#       <td id="T_5a64e_row1_col1" class="data row1 col1" >2.000000</td>
#       <td id="T_5a64e_row1_col2" class="data row1 col2" >4.000000</td>
#       <td id="T_5a64e_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_5a64e_row1_col4" class="data row1 col4" >3.000000</td>
#       <td id="T_5a64e_row1_col5" class="data row1 col5" >6.660000</td>
#       <td id="T_5a64e_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_5a64e_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_5a64e_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_5a64e_row1_col9" class="data row1 col9" >28206.000000</td>
#       <td id="T_5a64e_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_5a64e_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_5a64e_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_5a64e_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_5a64e_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_5a64e_row1_col15" class="data row1 col15" >121.800000</td>
#     </tr>
#     <tr>
#       <th id="T_5a64e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5a64e_row2_col0" class="data row2 col0" >14.080000</td>
#       <td id="T_5a64e_row2_col1" class="data row2 col1" >4.000000</td>
#       <td id="T_5a64e_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_5a64e_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_5a64e_row2_col4" class="data row2 col4" >3.000000</td>
#       <td id="T_5a64e_row2_col5" class="data row2 col5" >21.300000</td>
#       <td id="T_5a64e_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_5a64e_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_5a64e_row2_col8" class="data row2 col8" >26.000000</td>
#       <td id="T_5a64e_row2_col9" class="data row2 col9" >21215.000000</td>
#       <td id="T_5a64e_row2_col10" class="data row2 col10" >1.000000</td>
#       <td id="T_5a64e_row2_col11" class="data row2 col11" >0.000000</td>
#       <td id="T_5a64e_row2_col12" class="data row2 col12" >0.000000</td>
#       <td id="T_5a64e_row2_col13" class="data row2 col13" >0.000000</td>
#       <td id="T_5a64e_row2_col14" class="data row2 col14" >0.000000</td>
#       <td id="T_5a64e_row2_col15" class="data row2 col15" >83.51000
# <style type="text/css">
# #T_b643b caption {
#   color: darkblue;
#   font-size: 18px;
#   font-weight: bold;
# }
# #T_b643b_row0_col0, #T_b643b_row0_col1, #T_b643b_row0_col2, #T_b643b_row0_col3, #T_b643b_row0_col4, #T_b643b_row0_col5, #T_b643b_row0_col6, #T_b643b_row0_col7, #T_b643b_row0_col8, #T_b643b_row0_col9, #T_b643b_row0_col10, #T_b643b_row0_col11, #T_b643b_row0_col12, #T_b643b_row0_col13, #T_b643b_row0_col14, #T_b643b_row0_col15 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b643b_row1_col0, #T_b643b_row1_col1, #T_b643b_row1_col2, #T_b643b_row1_col3, #T_b643b_row1_col4, #T_b643b_row1_col5, #T_b643b_row1_col6, #T_b643b_row1_col7, #T_b643b_row1_col8, #T_b643b_row1_col10, #T_b643b_row1_col11, #T_b643b_row1_col12, #T_b643b_row1_col13, #T_b643b_row1_col14, #T_b643b_row1_col15, #T_b643b_row2_col0, #T_b643b_row2_col1, #T_b643b_row2_col2, #T_b643b_row2_col3, #T_b643b_row2_col4, #T_b643b_row2_col5, #T_b643b_row2_col6, #T_b643b_row2_col7, #T_b643b_row2_col8, #T_b643b_row2_col9, #T_b643b_row2_col10, #T_b643b_row2_col11, #T_b643b_row2_col12, #T_b643b_row2_col13, #T_b643b_row2_col14, #T_b643b_row2_col15, #T_b643b_row3_col0, #T_b643b_row3_col1, #T_b643b_row3_col2, #T_b643b_row3_col3, #T_b643b_row3_col4, #T_b643b_row3_col5, #T_b643b_row3_col6, #T_b643b_row3_col7, #T_b643b_row3_col8, #T_b643b_row3_col10, #T_b643b_row3_col11, #T_b643b_row3_col12, #T_b643b_row3_col13, #T_b643b_row3_col14, #T_b643b_row3_col15, #T_b643b_row4_col0, #T_b643b_row4_col1, #T_b643b_row4_col2, #T_b643b_row4_col3, #T_b643b_row4_col4, #T_b643b_row4_col5, #T_b643b_row4_col6, #T_b643b_row4_col7, #T_b643b_row4_col8, #T_b643b_row4_col10, #T_b643b_row4_col11, #T_b643b_row4_col12, #T_b643b_row4_col13, #T_b643b_row4_col14, #T_b643b_row4_col15, #T_b643b_row5_col0, #T_b643b_row5_col1, #T_b643b_row5_col2, #T_b643b_row5_col3, #T_b643b_row5_col4, #T_b643b_row5_col5, #T_b643b_row5_col6, #T_b643b_row5_col7, #T_b643b_row5_col8, #T_b643b_row5_col10, #T_b643b_row5_col11, #T_b643b_row5_col12, #T_b643b_row5_col13, #T_b643b_row5_col14, #T_b643b_row5_col15, #T_b643b_row6_col0, #T_b643b_row6_col1, #T_b643b_row6_col2, #T_b643b_row6_col3, #T_b643b_row6_col4, #T_b643b_row6_col5, #T_b643b_row6_col6, #T_b643b_row6_col7, #T_b643b_row6_col8, #T_b643b_row6_col10, #T_b643b_row6_col11, #T_b643b_row6_col12, #T_b643b_row6_col13, #T_b643b_row6_col14, #T_b643b_row6_col15, #T_b643b_row7_col0, #T_b643b_row7_col1, #T_b643b_row7_col2, #T_b643b_row7_col3, #T_b643b_row7_col4, #T_b643b_row7_col5, #T_b643b_row7_col6, #T_b643b_row7_col7, #T_b643b_row7_col8, #T_b643b_row7_col10, #T_b643b_row7_col11, #T_b643b_row7_col12, #T_b643b_row7_col13, #T_b643b_row7_col14, #T_b643b_row7_col15 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b643b_row1_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b643b_row3_col9 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b643b_row4_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b643b_row5_col9 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_b643b_row6_col9 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b643b_row7_col9 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# </style>
# <table id="T_b643b">
#   <caption>Summary Statistics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b643b_level0_col0" class="col_heading level0 col0" >store_sales(in millions)</th>
#       <th id="T_b643b_level0_col1" class="col_heading level0 col1" >unit_sales(in millions)</th>
#       <th id="T_b643b_level0_col2" class="col_heading level0 col2" >total_children</th>
#       <th id="T_b643b_level0_col3" class="col_heading level0 col3" >num_children_at_home</th>
#       <th id="T_b643b_level0_col4" class="col_heading level0 col4" >avg_cars_at home(approx).1</th>
#       <th id="T_b643b_level0_col5" class="col_heading level0 col5" >gross_weight</th>
#       <th id="T_b643b_level0_col6" class="col_heading level0 col6" >recyclable_package</th>
#       <th id="T_b643b_level0_col7" class="col_heading level0 col7" >low_fat</th>
#       <th id="T_b643b_level0_col8" class="col_heading level0 col8" >units_per_case</th>
#       <th id="T_b643b_level0_col9" class="col_heading level0 col9" >store_sqft</th>
#       <th id="T_b643b_level0_col10" class="col_heading level0 col10" >coffee_bar</th>
#       <th id="T_b643b_level0_col11" class="col_heading level0 col11" >video_store</th>
#       <th id="T_b643b_level0_col12" class="col_heading level0 col12" >salad_bar</th>
#       <th id="T_b643b_level0_col13" class="col_heading level0 col13" >prepared_food</th>
#       <th id="T_b643b_level0_col14" class="col_heading level0 col14" >florist</th>
#       <th id="T_b643b_level0_col15" class="col_heading level0 col15" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b643b_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_b643b_row0_col0" class="data row0 col0" >360336.000000</td>
#       <td id="T_b643b_row0_col1" class="data row0 col1" >360336.000000</td>
#       <td id="T_b643b_row0_col2" class="data row0 col2" >360336.000000</td>
#       <td id="T_b643b_row0_col3" class="data row0 col3" >360336.000000</td>
#       <td id="T_b643b_row0_col4" class="data row0 col4" >360336.000000</td>
#       <td id="T_b643b_row0_col5" class="data row0 col5" >360336.000000</td>
#       <td id="T_b643b_row0_col6" class="data row0 col6" >360336.000000</td>
#       <td id="T_b643b_row0_col7" class="data row0 col7" >360336.000000</td>
#       <td id="T_b643b_row0_col8" class="data row0 col8" >360336.000000</td>
#       <td id="T_b643b_row0_col9" class="data row0 col9" >360336.000000</td>
#       <td id="T_b643b_row0_col10" class="data row0 col10" >360336.000000</td>
#       <td id="T_b643b_row0_col11" class="data row0 col11" >360336.000000</td>
#       <td id="T_b643b_row0_col12" class="data row0 col12" >360336.000000</td>
#       <td id="T_b643b_row0_col13" class="data row0 col13" >360336.000000</td>
#       <td id="T_b643b_row0_col14" class="data row0 col14" >360336.000000</td>
#       <td id="T_b643b_row0_col15" class="data row0 col15" >360336.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b643b_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_b643b_row1_col0" class="data row1 col0" >6.337376</td>
#       <td id="T_b643b_row1_col1" class="data row1 col1" >3.043881</td>
#       <td id="T_b643b_row1_col2" class="data row1 col2" >2.456482</td>
#       <td id="T_b643b_row1_col3" class="data row1 col3" >0.689390</td>
#       <td id="T_b643b_row1_col4" class="data row1 col4" >2.203813</td>
#       <td id="T_b643b_row1_col5" class="data row1 col5" >13.822071</td>
#       <td id="T_b643b_row1_col6" class="data row1 col6" >0.568086</td>
#       <td id="T_b643b_row1_col7" class="data row1 col7" >0.327797</td>
#       <td id="T_b643b_row1_col8" class="data row1 col8" >18.972706</td>
#       <td id="T_b643b_row1_col9" class="data row1 col9" >28180.333442</td>
#       <td id="T_b643b_row1_col10" class="data row1 col10" >0.564839</td>
#       <td id="T_b643b_row1_col11" class="data row1 col11" >0.277394</td>
#       <td id="T_b643b_row1_col12" class="data row1 col12" >0.504807</td>
#       <td id="T_b643b_row1_col13" class="data row1 col13" >0.504832</td>
#       <td id="T_b643b_row1_col14" class="data row1 col14" >0.503191</td>
#       <td id="T_b643b_row1_col15" class="data row1 col15" >99.614729</td>
#     </tr>
#     <tr>
#       <th id="T_b643b_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_b643b_row2_col0" class="data row2 col0" >3.307980</td>
#       <td id="T_b643b_row2_col1" class="data row2 col1" >0.784676</td>
#       <td id="T_b643b_row2_col2" class="data row2 col2" >1.488992</td>
#       <td id="T_b643b_row2_col3" class="data row2 col3" >1.214732</td>
#       <td id="T_b643b_row2_col4" class="data row2 col4" >1.084293</td>
#       <td id="T_b643b_row2_col5" class="data row2 col5" >4.614792</td>
#       <td id="T_b643b_row2_col6" class="data row2 col6" >0.495343</td>
#       <td id="T_b643b_row2_col7" class="data row2 col7" >0.469411</td>
#       <td id="T_b643b_row2_col8" class="data row2 col8" >10.212912</td>
# <style type="text/css">
# #T_00f16 caption {
#   color: darkblue;
#   font-size: 18px;
#   font-weight: bold;
# }
# #T_00f16_row0_col0, #T_00f16_row0_col1, #T_00f16_row0_col2, #T_00f16_row0_col3, #T_00f16_row0_col4, #T_00f16_row0_col5, #T_00f16_row0_col6, #T_00f16_row0_col7, #T_00f16_row0_col8, #T_00f16_row0_col9, #T_00f16_row0_col10, #T_00f16_row0_col11, #T_00f16_row0_col12, #T_00f16_row0_col13, #T_00f16_row0_col14, #T_00f16_row0_col15 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_00f16">
#   <caption>Unique Value Counts In Each Column</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00f16_level0_col0" class="col_heading level0 col0" >store_sales(in millions)</th>
#       <th id="T_00f16_level0_col1" class="col_heading level0 col1" >unit_sales(in millions)</th>
#       <th id="T_00f16_level0_col2" class="col_heading level0 col2" >total_children</th>
#       <th id="T_00f16_level0_col3" class="col_heading level0 col3" >num_children_at_home</th>
#       <th id="T_00f16_level0_col4" class="col_heading level0 col4" >avg_cars_at home(approx).1</th>
#       <th id="T_00f16_level0_col5" class="col_heading level0 col5" >gross_weight</th>
#       <th id="T_00f16_level0_col6" class="col_heading level0 col6" >recyclable_package</th>
#       <th id="T_00f16_level0_col7" class="col_heading level0 col7" >low_fat</th>
#       <th id="T_00f16_level0_col8" class="col_heading level0 col8" >units_per_case</th>
#       <th id="T_00f16_level0_col9" class="col_heading level0 col9" >store_sqft</th>
#       <th id="T_00f16_level0_col10" class="col_heading level0 col10" >coffee_bar</th>
#       <th id="T_00f16_level0_col11" class="col_heading level0 col11" >video_store</th>
#       <th id="T_00f16_level0_col12" class="col_heading level0 col12" >salad_bar</th>
#       <th id="T_00f16_level0_col13" class="col_heading level0 col13" >prepared_food</th>
#       <th id="T_00f16_level0_col14" class="col_heading level0 col14" >florist</th>
#       <th id="T_00f16_level0_col15" class="col_heading level0 col15" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00f16_level0_row0" class="row_heading level0 row0" >Unique Value Count</th>
#       <td id="T_00f16_row0_col0" class="data row0 col0" >1044</td>
#       <td id="T_00f16_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_00f16_row0_col2" class="data row0 col2" >6</td>
#       <td id="T_00f16_row0_col3" class="data row0 col3" >6</td>
#       <td id="T_00f16_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_00f16_row0_col5" class="data row0 col5" >384</td>
#       <td id="T_00f16_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_00f16_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_00f16_row0_col8" class="data row0 col8" >36</td>
#       <td id="T_00f16_row0_col9" class="data row0 col9" >20</td>
#       <td id="T_00f16_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_00f16_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_00f16_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_00f16_row0_col13" class="data row0 col13" >2</td>
#       <td id="T_00f16_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_00f16_row0_col15" class="data row0 col15" >328</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8912a caption {
#   color: darkblue;
#   font-size: 18px;
#   font-weight: bold;
# }
# </style>
# <table id="T_8912a">
#   <caption>Columns With Nan</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8912a_level0_col0" class="col_heading level0 col0" >store_sales(in millions)</th>
#       <th id="T_8912a_level0_col1" class="col_heading level0 col1" >unit_sales(in millions)</th>
#       <th id="T_8912a_level0_col2" class="col_heading level0 col2" >total_children</th>
#       <th id="T_8912a_level0_col3" class="col_heading level0 col3" >num_children_at_home</th>
#       <th id="T_8912a_level0_col4" class="col_heading level0 col4" >avg_cars_at home(approx).1</th>
#       <th id="T_8912a_level0_col5" class="col_heading level0 col5" >gross_weight</th>
#       <th id="T_8912a_level0_col6" class="col_heading level0 col6" >recyclable_package</th>
#       <th id="T_8912a_level0_col7" class="col_heading level0 col7" >low_fat</th>
#       <th id="T_8912a_level0_col8" class="col_heading level0 col8" >units_per_case</th>
#       <th id="T_8912a_level0_col9" class="col_heading level0 col9" >store_sqft</th>
#       <th id="T_8912a_level0_col10" class="col_heading level0 col10" >coffee_bar</th>
#       <th id="T_8912a_level0_col11" class="col_heading level0 col11" >video_store</th>
#       <th id="T_8912a_level0_col12" class="col_heading level0 col12" >salad_bar</th>
#       <th id="T_8912a_level0_col13" class="col_heading level0 col13" >prepared_food</th>
#       <th id="T_8912a_level0_col14" class="col_heading level0 col14" >florist</th>
#       <th id="T_8912a_level0_col15" class="col_heading level0 col15" >cost</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8912a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8912a_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_8912a_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_8912a_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_8912a_row0_col3" class="data row0 col3" >False</td>
#       <td id="T_8912a_row0_col4" class="data row0 col4" >False</td>
#       <td id="T_8912a_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_8912a_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_8912a_row0_col7" class="data row0 col7" >False</td>
#       <td id="T_8912a_row0_col8" class="data row0 col8" >False</td>
#       <td id="T_8912a_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_8912a_row0_col10" class="data row0 col10" >False</td>
#       <td id="T_8912a_row0_col11" class="data row0 col11" >False</td>
#       <td id="T_8912a_row0_col12" class="data row0 col12" >False</td>
#       <td id="T_8912a_row0_col13" class="data row0 col13" >False</td>
#       <td id="T_8912a_row0_col14" class="data row0 col14" >False</td>
#       <td id="T_8912a_row0_col15" class="data row0 col15" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %matplotlib inline
from matplotlib import pyplot as plt 

train_df.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# This dataset is made of continuous variables (e.g., gross_weight) and binary, categorical variables (e.g., video_store). It has already been numerized, so we can skip this step.
#
# Let's compute the standard correlation coefficient (pearson) between the cost and all the attributes using the `corr()` method. These coefficients range from -1 to 1 (1 = positively correlated, 0 = no correlation, -1 = negatively correlated)

# %%
corr_matrix = train_df.corr()
corr_matrix['cost'].sort_values(ascending=False)
# Out:
# cost                          1.000000
# avg_cars_at home(approx).1    0.027098
# units_per_case                0.000180
# gross_weight                 -0.000116
# recyclable_package           -0.001455
# num_children_at_home         -0.001727
# low_fat                      -0.001975
# total_children               -0.007482
# store_sales(in millions)     -0.012387
# unit_sales(in millions)      -0.026509
# store_sqft                   -0.049201
# coffee_bar                   -0.052086
# salad_bar                    -0.098810
# prepared_food                -0.098843
# video_store                  -0.106786
# florist                      -0.110414
# Name: cost, dtype: float64

# %% [markdown]
# They all have quite a low correlation coefficient, so they all seem individually unable to explain the cost.

# %%
# create mask for upper triangle
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Create heatmap
plt.figure(figsize=(10, 6))
# set theme to change overall style
sns.set_theme(style="white", font_scale=0.7)
sns.heatmap(corr_matrix, cmap="cool", linewidths=2, mask=mask, vmin=-1, vmax=1, annot=True, fmt=".2f")
plt.title("Correlation Matrix", fontsize=16, weight = 'bold', pad=20)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# It looks like prepared_food and salad_bar are basically identical. We can then remove some features that have low correlation, some that are redundant, and I thank one of the guys in the discussion who found other feartures who are removable

# %%
selected_features = [
 'total_children',
 'num_children_at_home',
 'avg_cars_at home(approx).1',
 'store_sqft',
 'coffee_bar',
 'video_store',
 'salad_bar',
 'florist',
]

selected_features_test = [
    'id',
 'total_children',
 'num_children_at_home',
 'avg_cars_at home(approx).1',
 'store_sqft',
 'coffee_bar',
 'video_store',
 'salad_bar',
 'florist',
]

# %%
X = np.array(train_df[selected_features].values)
X_test = np.array(test_df[selected_features].values)

y = np.array(train_df['cost'])
print(X.shape)
# Out:
# (360336, 8)

# %% [markdown]
# Let's train our first scikit-learn linear regression. For this, we can use Scikit learn K-fold cross-validation feature, that randomly splits the training set into K disctinct subsets called folds, then it trains and evaluates the model K times, picking a different fold for evlauation every time and training on the other folds. The result is an array containing the K evaluation scores.

# %%
from sklearn.linear_model import LinearRegression 
lin_reg = LinearRegression()
lin_reg.fit(X, y)

from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer 
from sklearn.metrics import mean_squared_log_error


rmsle_scorer = make_scorer(mean_squared_log_error, greater_is_better=False)

scores = cross_validate(lin_reg, X, y, scoring=rmsle_scorer, cv=5, return_train_score=True)

def display_rmse_scores(scores):
#     rmse_scores =  np.sqrt(-scores)
    print("Training score:", (-scores['train_score'].mean())**0.5)
    print("Validation score:", (-scores['test_score'].mean())**0.5)
display_rmse_scores(scores)
# Out:
# Training score: 0.31695175487141636
# Validation score: 0.3169644619964467

# %% [markdown]
# We can now use Gradient Boosting. It works by sequentially adding predictors to an ensemble, each one correcting its predecessor. It particularly tries to fit the new predictor to the residual errors made by the previous predictor. Let's first split data into train and validation sets, as I don't want to use cross validation (takes too much time).
#
# Note that the evaluation metric is RMSLE (Root Mean Squared Logarithmic Error), so transforming labels might yield better results since these regression models minimize loss functions on a MSE metric.

# %%
from sklearn.model_selection import train_test_split 

X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.metrics import mean_squared_log_error

gbrt = GradientBoostingRegressor(max_depth=2, n_estimators=5, warm_start=True)
gbrt.fit(X_train, np.log1p(y_train))


min_val_error = float("inf")
error_going_up = 0
# Let's gradually increase the number of estimators and check which model is best: perform early stopping with patience of 3 
for n_estimators in range(10, 100, 10):
    gbrt.n_estimators = n_estimators
    gbrt.fit(X_train, np.log1p(y_train))
    y_pred = np.expm1(gbrt.predict(X_val))
    val_error = mean_squared_log_error(y_val, y_pred)**0.5
    print("With "+str(n_estimators)+" estimators, val error = "+str(val_error))
    if val_error < min_val_error:
        min_val_error = val_error
        error_going_up=0
    else:
        error_going_up +=1
        if error_going_up==3:
            break # early stopping
# Out:
# With 10 estimators, val error = 0.312028980113256
# With 20 estimators, val error = 0.3100294189673871
# With 30 estimators, val error = 0.30867093195178175
# With 40 estimators, val error = 0.3080524490125292
# With 50 estimators, val error = 0.30761412443383956
# With 60 estimators, val error = 0.30728889059339776
# With 70 estimators, val error = 0.306982678879632
# With 80 estimators, val error = 0.30670932583082916
# With 90 estimators, val error = 0.3064700597700389

# %% [markdown]
# Not great, we can increase n_estimators to 1000 or more, but it will take a long time for not so much increase. Now let's try with XGBoost and early stopping with 20 of patience

# %%
import xgboost as xgb
import optuna


#Train Extreme Gradient Boosting Model

#Create D-matrices for training and validation sets

DM_0=xgb.DMatrix(X_train,y_train)
DM_1=xgb.DMatrix(X_val,y_val)


glob_params = {
    'tree_method': 'hist',
    'objective': 'reg:squaredlogerror',
    'eval_metric': 'rmsle',
    'n_estimators': 9999
}



def objective(trial):
    params = {
        'verbosity':0,
        'learning_rate': trial.suggest_float('learning_rate',1e-10,1.0),
        'max_depth':trial.suggest_int('max_depth', 3, 12),
#        'gamma':trial.suggest_float('gamma',0,8),
        'min_child_weight':trial.suggest_int('min_child_weight',0,1),
        'booster':trial.suggest_categorical("booster", ["dart", "gbtree",'gblinear']),
        'sampling_method': trial.suggest_categorical('sampling_method',['uniform','gradient_based']),
        'grow_policy': trial.suggest_categorical('grow_policy',['depthwise','lossguide']),
        'reg_alpha': trial.suggest_float("reg_alpha", 0, 1),
        'reg_lambda': trial.suggest_float("reg_lambda", 0, 1),
    }
    params.update(glob_params)
    sch_prm = xgb.train(params, DM_0, num_boost_round = 100,
                        evals = [(DM_1, 'valid')], 
                        early_stopping_rounds=20, verbose_eval=False
                       )
    
    return sch_prm.best_score

# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials = 500,)

# Simple XGBoost Params
best_params = {'n_estimators': 100, # not imp
             'learning_rate': 0.7, # + or - bad
             'max_depth': 12, # - bad + bad
             'lambda': 0.0150, # + bad 
             'alpha': 1.0e-08, # - is little good
             'colsample_bytree': 0.7, # imp (adding randomness to the training process.)
             'min_child_weight': 0, # + bad
             'booster': 'gbtree',
             'grow_policy': 'depthwise', 
             'tree_method': 'hist',
             'objective': 'reg:squaredlogerror',
             'eval_metric': 'rmsle',
             'random_state': 17}


# best_params.update(glob_params)

xgbr = xgb.train(
    dtrain=DM_0,
    num_boost_round=2000,
    params=best_params,
    early_stopping_rounds=20,
    evals=[(DM_0, 'train'), (DM_1, 'eval')],
    verbose_eval=True
)
# Out:
# [0]	train-rmsle:3.53438	eval-rmsle:3.53519
# [1]	train-rmsle:3.10125	eval-rmsle:3.10204
# [2]	train-rmsle:2.67940	eval-rmsle:2.68017
# [3]	train-rmsle:2.27145	eval-rmsle:2.27220
# [4]	train-rmsle:1.88089	eval-rmsle:1.88162
# [5]	train-rmsle:1.51255	eval-rmsle:1.51324
# [6]	train-rmsle:1.17349	eval-rmsle:1.17415
# [7]	train-rmsle:0.87299	eval-rmsle:0.87355
# [8]	train-rmsle:0.62507	eval-rmsle:0.62547
# [9]	train-rmsle:0.44705	eval-rmsle:0.44719
# [10]	train-rmsle:0.34908	eval-rmsle:0.34898
# [11]	train-rmsle:0.31343	eval-rmsle:0.31313
# [12]	train-rmsle:0.30531	eval-rmsle:0.30502
# [13]	train-rmsle:0.30351	eval-rmsle:0.30314
# [14]	train-rmsle:0.30272	eval-rmsle:0.30237
# [15]	train-rmsle:0.30210	eval-rmsle:0.30181
# [16]	train-rmsle:0.30175	eval-rmsle:0.30152
# [17]	train-rmsle:0.29991	eval-rmsle:0.29974
# [18]	train-rmsle:0.29816	eval-rmsle:0.29824
# [19]	train-rmsle:0.29774	eval-rmsle:0.29786
# [20]	train-rmsle:0.29772	eval-rmsle:0.29785
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [10:00:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "n_estimators" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [21]	train-rmsle:0.29526	eval-rmsle:0.29563
# [22]	train-rmsle:0.29410	eval-rmsle:0.29468
# [23]	train-rmsle:0.29332	eval-rmsle:0.29407
# [24]	train-rmsle:0.29309	eval-rmsle:0.29388
# [25]	train-rmsle:0.29307	eval-rmsle:0.29385
# [26]	train-rmsle:0.29300	eval-rmsle:0.29379
# [27]	train-rmsle:0.29292	eval-rmsle:0.29373
# [28]	train-rmsle:0.29289	eval-rmsle:0.29370
# [29]	train-rmsle:0.29284	eval-rmsle:0.29368
# [30]	train-rmsle:0.29282	eval-rmsle:0.29366
# [31]	train-rmsle:0.29277	eval-rmsle:0.29363
# [32]	train-rmsle:0.29276	eval-rmsle:0.29362
# [33]	train-rmsle:0.29275	eval-rmsle:0.29361
# [34]	train-rmsle:0.29271	eval-rmsle:0.29357
# [35]	train-rmsle:0.29269	eval-rmsle:0.29357
# [36]	train-rmsle:0.29264	eval-rmsle:0.29352
# [37]	train-rmsle:0.29264	eval-rmsle:0.29351
# [38]	train-rmsle:0.29251	eval-rmsle:0.29341
# [39]	train-rmsle:0.29251	eval-rmsle:0.29341
# [40]	train-rmsle:0.29249	eval-rmsle:0.29341
# [41]	train-rmsle:0.29245	eval-rmsle:0.29339
# [42]	train-rmsle:0.29223	eval-rmsle:0.29323
# [43]	train-rmsle:0.29221	eval-rmsle:0.29321
# [44]	train-rmsle:0.29221	eval-rmsle:0.29321
# [45]	train-rmsle:0.29216	eval-rmsle:0.29318
# [46]	train-rmsle:0.29216	eval-rmsle:0.29318
# [47]	train-rmsle:0.29214	eval-rmsle:0.29316
# [48]	train-rmsle:0.29213	eval-rmsle:0.29316
# [49]	train-rmsle:0.29212	eval-rmsle:0.29316
# [50]	train-rmsle:0.29212	eval-rmsle:0.29315
# [51]	train-rmsle:0.29210	eval-rmsle:0.29314
# [52]	train-rmsle:0.29210	eval-rmsle:0.29315
# [53]	train-rmsle:0.29208	eval-rmsle:0.29315
# [54]	train-rmsle:0.29208	eval-rmsle:0.29315
# [55]	train-rmsle:0.29206	eval-rmsle:0.29314
# [56]	train-rmsle:0.29205	eval-rmsle:0.29313
# [57]	train-rmsle:0.29204	eval-rmsle:0.29313
# [58]	train-rmsle:0.29204	eval-rmsle:0.29313
# [59]	train-rmsle:0.29203	eval-rmsle:0.29312
# [60]	train-rmsle:0.29202	eval-rmsle:0.29312
# [61]	train-rmsle:0.29202	eval-rmsle:0.29312
# [62]	train-rmsle:0.29201	eval-rmsle:0.29312
# [63]	train-rmsle:0.29201	eval-rmsle:0.29312
# [64]	train-rmsle:0.29201	eval-rmsle:0.29312
# [65]	train-rmsle:0.29199	eval-rmsle:0.29311
# [66]	train-rmsle:0.29199	eval-rmsle:0.29311
# [67]	train-rmsle:0.29198	eval-rmsle:0.29311
# [68]	train-rmsle:0.29198	eval-rmsle:0.29310
# [69]	train-rmsle:0.29198	eval-rmsle:0.29310
# [70]	train-rmsle:0.29197	eval-rmsle:0.29310
# [71]	train-rmsle:0.29196	eval-rmsle:0.29310
# [72]	train-rmsle:0.29195	eval-rmsle:0.29310
# [73]	train-rmsle:0.29194	eval-rmsle:0.29309
# [74]	train-rmsle:0.29193	eval-rmsle:0.29308
# [75]	train-rmsle:0.29193	eval-rmsle:0.29308
# [76]	train-rmsle:0.29193	eval-rmsle:0.29308
# [77]	train-rmsle:0.29187	eval-rmsle:0.29303
# [78]	train-rmsle:0.29187	eval-rmsle:0.29303
# [79]	train-rmsle:0.29186	eval-rmsle:0.29303
# [80]	train-rmsle:0.29186	eval-rmsle:0.29303
# [81]	train-rmsle:0.29186	eval-rmsle:0.29303
# [82]	train-rmsle:0.29186	eval-rmsle:0.29303
# [83]	train-rmsle:0.29186	eval-rmsle:0.29303
# [84]	train-rmsle:0.29186	eval-rmsle:0.29303
# [85]	train-rmsle:0.29186	eval-rmsle:0.29303
# [86]	train-rmsle:0.29185	eval-rmsle:0.29303
# [87]	train-rmsle:0.29185	eval-rmsle:0.29303
# [88]	train-rmsle:0.29184	eval-rmsle:0.29302
# [89]	train-rmsle:0.29184	eval-rmsle:0.29302
# [90]	train-rmsle:0.29183	eval-rmsle:0.29302
# [91]	train-rmsle:0.29183	eval-rmsle:0.29302
# [92]	train-rmsle:0.29183	eval-rmsle:0.29302
# [93]	train-rmsle:0.29182	eval-rmsle:0.29302
# [94]	train-rmsle:0.29182	eval-rmsle:0.29302
# [95]	train-rmsle:0.29182	eval-rmsle:0.29302
# [96]	train-rmsle:0.29181	eval-rmsle:0.29302
# [97]	train-rmsle:0.29181	eval-rmsle:0.29302
# [98]	train-rmsle:0.29181	eval-rmsle:0.29302
# [99]	train-rmsle:0.29181	eval-rmsle:0.29302
# [100]	train-rmsle:0.29180	eval-rmsle:0.29302
# [101]	train-rmsle:0.29180	eval-rmsle:0.29301
# [102]	train-rmsle:0.29180	eval-rmsle:0.29301
# [103]	train-rmsle:0.29180	eval-rmsle:0.29301
# [104]	train-rmsle:0.29180	eval-rmsle:0.29301
# [105]	train-rmsle:0.29180	eval-rmsle:0.29301
# [106]	train-rmsle:0.29180	eval-rmsle:0.29301
# [107]	train-rmsle:0.29180	eval-rmsle:0.29301
# [108]	train-rmsle:0.29179	eval-rmsle:0.29301
# [109]	train-rmsle:0.29179	eval-rmsle:0.29302
# [110]	train-rmsle:0.29179	eval-rmsle:0.29301
# [111]	train-rmsle:0.29179	eval-rmsle:0.29301
# [112]	train-rmsle:0.29176	eval-rmsle:0.29299
# [113]	train-rmsle:0.29176	eval-rmsle:0.29300
# [114]	train-rmsle:0.29176	eval-rmsle:0.29299
# [115]	train-rmsle:0.29175	eval-rmsle:0.29299
# [116]	train-rmsle:0.29175	eval-rmsle:0.29299
# [117]	train-rmsle:0.29175	eval-rmsle:0.29299
# [118]	train-rmsle:0.29175	eval-rmsle:0.29299
# [119]	train-rmsle:0.29175	eval-rmsle:0.29299
# [120]	train-rmsle:0.29175	eval-rmsle:0.29299
# [121]	train-rmsle:0.29174	eval-rmsle:0.29299
# [122]	train-rmsle:0.29174	eval-rmsle:0.29299
# [123]	train-rmsle:0.29174	eval-rmsle:0.29299
# [124]	train-rmsle:0.29174	eval-rmsle:0.29299
# [125]	train-rmsle:0.29174	eval-rmsle:0.29299
# [126]	train-rmsle:0.29174	eval-rmsle:0.29299
# [127]	train-rmsle:0.29173	eval-rmsle:0.29299
# [128]	train-rmsle:0.29173	eval-rmsle:0.29299
# [129]	train-rmsle:0.29173	eval-rmsle:0.29299
# [130]	train-rmsle:0.29173	eval-rmsle:0.29299
# [131]	train-rmsle:0.29172	eval-rmsle:0.29299
# [132]	train-rmsle:0.29172	eval-rmsle:0.29299
# [133]	train-rmsle:0.29172	eval-rmsle:0.29299
# [134]	train-rmsle:0.29172	eval-rmsle:0.29299
# [135]	train-rmsle:0.29172	eval-rmsle:0.29299
# [136]	train-rmsle:0.29172	eval-rmsle:0.29299
# [137]	train-rmsle:0.29172	eval-rmsle:0.29299
# [138]	train-rmsle:0.29172	eval-rmsle:0.29299
# [139]	train-rmsle:0.29172	eval-rmsle:0.29299
# [140]	train-rmsle:0.29171	eval-rmsle:0.29299
# [141]	train-rmsle:0.29171	eval-rmsle:0.29299
# [142]	train-rmsle:0.29171	eval-rmsle:0.29299
# [143]	train-rmsle:0.29171	eval-rmsle:0.29299
# [144]	train-rmsle:0.29171	eval-rmsle:0.29299
# [145]	train-rmsle:0.29171	eval-rmsle:0.29299
# [146]	train-rmsle:0.29171	eval-rmsle:0.29300
# [147]	train-rmsle:0.29171	eval-rmsle:0.29300
# [148]	train-rmsle:0.29170	eval-rmsle:0.29300
# [149]	train-rmsle:0.29170	eval-rmsle:0.29300

# %%
DM_test=xgb.DMatrix(X_test) 
submission_df = test_df['id']
prediction = xgbr.predict(DM_test)
pred_df = pd.DataFrame(prediction, columns=['cost'])
submission_df = pd.concat([test_df['id'], pred_df],axis=1).fillna(0)
submission_df.to_csv('cost_prediction.csv', index=False)

# %%
submission_df.head()
# Out:
#        id       cost
# 0  360336  90.401085
# 1  360337  93.663284
# 2  360338  94.554787
# 3  360339  98.659988
# 4  360340  78.232811
